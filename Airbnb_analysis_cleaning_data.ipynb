# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.1/670.1 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import pymongo

# %% [markdown]
# Mongodb connection

# %%
conn=pymongo.MongoClient("mongodb://raji_sweeti:guvi2024@ac-nr8vpka-shard-00-00.vrmcz0d.mongodb.net:27017,ac-nr8vpka-shard-00-01.vrmcz0d.mongodb.net:27017,ac-nr8vpka-shard-00-02.vrmcz0d.mongodb.net:27017/?ssl=true&replicaSet=atlas-oe657d-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")
db=conn['sample_airbnb']
col=db['listingsAndReviews']

# %% [markdown]
# Collecting data

# %%
airbnb_data = []
for i in col.find():
    data = dict(Listing_url = i['listing_url'],
                Name = i.get('name'),
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds = i.get('beds'),
                No_of_reviews = i['number_of_reviews'],
                Bathrooms = i.get('bathrooms'),
                Amenities = ', '.join(i['amenities']),
                Price = i['price'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Host_location = i['host']['host_location'],
                Host_response_time = i['host'].get('host_response_time'),
                Host_neighbourhood =  i['host']['host_neighbourhood'],
                Host_verification = ','.join(i['host']['host_verifications']),
                Street = i['address']['street'],
                Market = i['address']['market'],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact'],
                Availability_30= i['availability']['availability_30'],
                Availability_60 = i['availability']['availability_60'],
                Availability_90 = i['availability']['availability_90'],
                Availability_365 = i['availability']['availability_365'],
                Review_scores = i['review_scores'].get('review_scores_rating')
    )
    airbnb_data.append(data)

# %%
df=pd.DataFrame(airbnb_data)
df
# Out:
#                                 Listing_url  \
# 0     https://www.airbnb.com/rooms/10006546
# 1     https://www.airbnb.com/rooms/10009999
# 2      https://www.airbnb.com/rooms/1001265
# 3     https://www.airbnb.com/rooms/10021707
# 4     https://www.airbnb.com/rooms/10030955
# ...                                     ...
# 5550   https://www.airbnb.com/rooms/9983221
# 5551   https://www.airbnb.com/rooms/9985696
# 5552   https://www.airbnb.com/rooms/9987200
# 5553   https://www.airbnb.com/rooms/9990304
# 5554   https://www.airbnb.com/rooms/9993190
#
#                                                    Name Property_type  \
# 0                               Ribeira Charming Duplex         House
# 1                          Horto flat with small garden     Apartment
# 2                      Ocean View Waikiki Marina w/prkg   Condominium
# 3                              Private Room in Bushwick     Apartment
# 4                           Apt Linda Vista Lagoa - Rio     Apartment
# ...

# %% [markdown]
# Cleaning dataset
# 1.missing values
# 2.duplicates
# 3.outliers
# 4.structured data
# 5.incorrect format

# %% [markdown]
# Checking format data types

# %%
df.dtypes
# Out:
# Listing_url             object
# Name                    object
# Property_type           object
# Room_type               object
# Bed_type                object
# Min_nights               int64
# Max_nights               int64
# Cancellation_policy     object
# Accomodates              int64
# Total_bedrooms         float64
# Total_beds             float64
# No_of_reviews            int64
# Bathrooms               object
# Amenities               object
# Price                   object
# Security_deposit        object
# Cleaning_fee            object
# Extra_people            object
# Guests_included         object
# Host_id                 object
# Host_name               object
# Host_location           object
# Host_response_time      object
# Host_neighbourhood      object
# Host_verification       object
# Street                  object
# Market                  object
# Country                 object
# Country_code            object
# Longitude              float64
# ...

# %% [markdown]
# Converting incorrect data types

# %%
# Convert columns to relevant data types

df['Total_beds'] = df['Total_beds'][~df['Total_beds'].isna()].astype(int)
df['Bathrooms'] = df['Bathrooms'][~df['Bathrooms'].isna()].astype(str).astype(float).astype(int)

# Convert 'Price' column to float
df['Price'] = df['Price'].astype(str).astype(float)

# Convert 'Security_deposit' column to float, handling NaN values
df['Security_deposit'] = df['Security_deposit'][~df['Security_deposit'].isna()].astype(str).astype(float)

# Convert 'Cleaning_fee' column to float, handling NaN values
df['Cleaning_fee'] = df['Cleaning_fee'][~df['Cleaning_fee'].isna()].astype(str).astype(float)

# Convert 'Extra_people' column to float
df['Extra_people'] = df['Extra_people'].astype(str).astype(float).astype(int)

# Convert 'Guests_included' column to float
df['Guests_included'] = df['Guests_included'].astype(str).astype(float).astype(int)

# Convert 'Guests_included' column to float
df['Host_id'] = df['Host_id'].astype(str).astype(int)

# %%
df.dtypes
# Out:
# Listing_url             object
# Name                    object
# Property_type           object
# Room_type               object
# Bed_type                object
# Min_nights               int64
# Max_nights               int64
# Cancellation_policy     object
# Accomodates              int64
# Total_bedrooms         float64
# Total_beds             float64
# No_of_reviews            int64
# Bathrooms              float64
# Amenities               object
# Price                  float64
# Security_deposit       float64
# Cleaning_fee           float64
# Extra_people             int64
# Guests_included          int64
# Host_id                  int64
# Host_name               object
# Host_location           object
# Host_response_time      object
# Host_neighbourhood      object
# Host_verification       object
# Street                  object
# Market                  object
# Country                 object
# Country_code            object
# Longitude              float64
# ...

# %%
c=list(df.columns)

# %%
c
# Out:
# ['Listing_url',
#  'Name',
#  'Property_type',
#  'Room_type',
#  'Bed_type',
#  'Min_nights',
#  'Max_nights',
#  'Cancellation_policy',
#  'Accomodates',
#  'Total_bedrooms',
#  'Total_beds',
#  'No_of_reviews',
#  'Bathrooms',
#  'Amenities',
#  'Price',
#  'Security_deposit',
#  'Cleaning_fee',
#  'Extra_people',
#  'Guests_included',
#  'Host_id',
#  'Host_name',
#  'Host_location',
#  'Host_response_time',
#  'Host_neighbourhood',
#  'Host_verification',
#  'Street',
#  'Market',
#  'Country',
#  'Country_code',
#  'Longitude',
#  'Latitude',
#  'Is_location_exact',
#  'Availability_30',
#  'Availability_60',
#  'Availability_90',
#  'Availability_365',
#  'Review_scores']

# %% [markdown]
# Missing values

# %%
df.isnull().sum()
# Out:
# Listing_url               0
# Name                      0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            5
# Total_beds               13
# No_of_reviews             0
# Bathrooms                10
# Amenities                 0
# Price                     0
# Security_deposit       2084
# Cleaning_fee           1531
# Extra_people              0
# Guests_included           0
# Host_id                   0
# Host_name                 0
# Host_location             0
# Host_response_time     1388
# Host_neighbourhood        0
# Host_verification         0
# Street                    0
# Market                    0
# Country                   0
# Country_code              0
# Longitude                 0
# Latitude                  0
# Is_location_exact         0
# Availability_30           0
# ...

# %%
df.isna().sum()
# Out:
# Listing_url               0
# Name                      0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            5
# Total_beds               13
# No_of_reviews             0
# Bathrooms                10
# Amenities                 0
# Price                     0
# Security_deposit       2084
# Cleaning_fee           1531
# Extra_people              0
# Guests_included           0
# Host_id                   0
# Host_name                 0
# Host_location             0
# Host_response_time     1388
# Host_neighbourhood        0
# Host_verification         0
# Street                    0
# Market                    0
# Country                   0
# Country_code              0
# Longitude                 0
# Latitude                  0
# Is_location_exact         0
# Availability_30           0
# ...

# %%
if df.isna().sum().any() > 0:
    print("Columns with missing Nan values:")
    Nan=df.columns[df.isna().any()].tolist()
    print(Nan)
# Out:
# Columns with missing Nan values:
# ['Total_bedrooms', 'Total_beds', 'Bathrooms', 'Security_deposit', 'Cleaning_fee', 'Host_response_time', 'Review_scores']

# %%
#categorical data columns
cat_col=cat_col = df.select_dtypes(include=['object', 'bool']).columns
cat_col
# Out:
# Index(['Listing_url', 'Name', 'Property_type', 'Room_type', 'Bed_type',
#        'Cancellation_policy', 'Amenities', 'Host_name', 'Host_location',
#        'Host_response_time', 'Host_neighbourhood', 'Host_verification',
#        'Street', 'Market', 'Country', 'Country_code', 'Is_location_exact'],
#       dtype='object')

# %%
#continous data column
cont_col=df.select_dtypes(exclude=['object','bool']).columns
columns_to_remove = ['Host_id', 'Longitude', 'Latitude']
cont_col=cont_col.drop(columns_to_remove)
cont_col
# Out:
# Index(['Min_nights', 'Max_nights', 'Accomodates', 'Total_bedrooms',
#        'Total_beds', 'No_of_reviews', 'Bathrooms', 'Price', 'Security_deposit',
#        'Cleaning_fee', 'Extra_people', 'Guests_included', 'Availability_30',
#        'Availability_60', 'Availability_90', 'Availability_365',
#        'Review_scores'],
#       dtype='object')

# %% [markdown]
# Checking outliers
# if max is greater than upper hreshold or min is smaller than lower threshold there is a outlier

# %%
for column in cont_col:

    print(f"Column : {column}")

    iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
    upper_threshold = df[column].quantile(0.75) + (1.5 * iqr)
    lower_threshold = df[column].quantile(0.25) - (1.5 * iqr)
    print(f"UpperThreshold : {upper_threshold} and lowerThreshold : {lower_threshold}")
    print(df[column].describe())

    print('**********************')
# Out:
# Column : Min_nights
# UpperThreshold : 6.0 and lowerThreshold : -2.0
# count    5555.000000
# mean        5.564356
# std        22.613861
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max      1250.000000
# Name: Min_nights, dtype: float64
# **********************
# Column : Max_nights
# UpperThreshold : 2724.0 and lowerThreshold : -1540.0
# count    5.555000e+03
# mean     1.382776e+06
# std      5.256920e+07
# min      1.000000e+00
# 25%      5.900000e+01
# 50%      1.125000e+03
# 75%      1.125000e+03
# max      2.147484e+09
# Name: Max_nights, dtype: float64
# **********************
# Column : Accomodates
# UpperThreshold : 7.0 and lowerThreshold : -1.0
# count    5555.000000
# mean        3.505851
# std         2.297019
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        16.000000
# Name: Accomodates, dtype: float64
# **********************
# Column : Total_bedrooms
# ...

# %% [markdown]
# Filling missing values

# %%
# Fill missing values in 'Total_bedrooms' with the mode
df['Total_bedrooms'].fillna(df['Total_bedrooms'].median(), inplace=True)

# Fill missing values in 'Total_beds' with the median due to outliers
df['Total_beds'].fillna(df['Total_beds'].median(), inplace=True)

df['Bathrooms'].fillna(df['Bathrooms'].median(), inplace=True)

# Fill missing values in 'Security_deposit' with the median due to outliers
df['Security_deposit'].fillna(df['Security_deposit'].median(), inplace=True)

# Fill missing values in 'Cleaning_fee' with the median due to outliers
df['Cleaning_fee'].fillna(df['Cleaning_fee'].median(), inplace=True)

# Fill missing values in 'Review_scores' with the median due to outliers
df['Review_scores'].fillna(df['Review_scores'].median(), inplace=True)

# %%
df['Host_response_time'].fillna(df['Host_response_time'].mode()[0], inplace=True)

# %%
if df.isna().sum().any() > 0:
    print("Columns with missing Nan values:")
    Nan=df.columns[df.isna().any()].tolist()
    print(Nan)

# %%
# Check for empty strings in each cell of the DataFrame
empty_strings = df.applymap(lambda x: x == '')

# Get the column names with empty strings
columns_with_empty_strings = empty_strings.any()

# Print the column names with empty strings
print("Columns with empty strings:")
print(columns_with_empty_strings[columns_with_empty_strings].index.tolist())
# Out:
# Columns with empty strings:
# ['Name', 'Amenities', 'Host_location', 'Host_neighbourhood', 'Host_verification', 'Market']

# %%
df["Name"].replace({'':"Not Specified"},inplace=True)
df["Amenities"].replace({'':"Not Specified"},inplace=True)
df["Host_location"].replace({'':"Not Specified"},inplace=True)
df["Host_neighbourhood"].replace({'':"Not Specified"},inplace=True)
df["Host_verification"].replace({'':"Not Specified"},inplace=True)
df["Market"].replace({'':"Not Specified"},inplace=True)

# %%
# Check for empty strings in each cell of the DataFrame
empty_strings = df.applymap(lambda x: x == '')

# Get the column names with empty strings
columns_with_empty_strings = empty_strings.any()

# Print the column names with empty strings
print("Columns with empty strings:")
print(columns_with_empty_strings[columns_with_empty_strings].index.tolist())
# Out:
# Columns with empty strings:
# []

# %% [markdown]
# Checking if duplicates exist

# %%
df.shape
# Out:
# (5555, 37)

# %%
df.drop_duplicates
df.shape
# Out:
# (5555, 37)

# %% [markdown]
# Removing outliers and checking

# %%
for column in cont_col:

    print(f"Column : {column}")

    iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
    upper_threshold = df[column].quantile(0.75) + (1.5 * iqr)
    lower_threshold = df[column].quantile(0.25) - (1.5 * iqr)
    print(f"UpperThreshold : {upper_threshold} and lowerThreshold : {lower_threshold}")

    df[column] = df[column].clip(lower_threshold, upper_threshold)   #cliping- removing outliers
    print(df[column].describe())


    print('**********************')
# Out:
# Column : Min_nights
# UpperThreshold : 6.0 and lowerThreshold : -2.0
# count    5555.000000
# mean        2.609001
# std         1.704954
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: Min_nights, dtype: float64
# **********************
# Column : Max_nights
# UpperThreshold : 2724.0 and lowerThreshold : -1540.0
# count    5555.000000
# mean      712.823402
# std       519.587550
# min         1.000000
# 25%        59.000000
# 50%      1125.000000
# 75%      1125.000000
# max      2724.000000
# Name: Max_nights, dtype: float64
# **********************
# Column : Accomodates
# UpperThreshold : 7.0 and lowerThreshold : -1.0
# count    5555.000000
# mean        3.329613
# std         1.784152
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         7.000000
# Name: Accomodates, dtype: float64
# **********************
# Column : Total_bedrooms
# ...

# %%
df['Total_bedrooms'] = df['Total_bedrooms'].astype(int)
df['Total_beds'] = df['Total_beds'].astype(int)
df['Bathrooms'] = df['Bathrooms'].astype(str).astype(float).astype(int)

# %%
df.dtypes
# Out:
# Listing_url             object
# Name                    object
# Property_type           object
# Room_type               object
# Bed_type                object
# Min_nights               int64
# Max_nights               int64
# Cancellation_policy     object
# Accomodates              int64
# Total_bedrooms           int64
# Total_beds               int64
# No_of_reviews          float64
# Bathrooms                int64
# Amenities               object
# Price                  float64
# Security_deposit       float64
# Cleaning_fee           float64
# Extra_people             int64
# Guests_included        float64
# Host_id                  int64
# Host_name               object
# Host_location           object
# Host_response_time      object
# Host_neighbourhood      object
# Host_verification       object
# Street                  object
# Market                  object
# Country                 object
# Country_code            object
# Longitude              float64
# ...

# %%
df['Guests_included'] = df['Guests_included'].astype(int)   # while cliping converted as float changing to int

# %%
df.dtypes
# Out:
# Listing_url             object
# Name                    object
# Property_type           object
# Room_type               object
# Bed_type                object
# Min_nights               int64
# Max_nights               int64
# Cancellation_policy     object
# Accomodates              int64
# Total_bedrooms           int64
# Total_beds               int64
# No_of_reviews          float64
# Bathrooms                int64
# Amenities               object
# Price                  float64
# Security_deposit       float64
# Cleaning_fee           float64
# Extra_people             int64
# Guests_included          int64
# Host_id                  int64
# Host_name               object
# Host_location           object
# Host_response_time      object
# Host_neighbourhood      object
# Host_verification       object
# Street                  object
# Market                  object
# Country                 object
# Country_code            object
# Longitude              float64
# ...

# %%
df.to_csv("airbnb_analysis_data.csv",index=False)
